# %%
# import tools 
import pandas as pd 
import seaborn as sns 
import numpy as np 
import matplotlib.pyplot as plt

# %%
fname = 'BayArea_df.xlsx'
df1 = pd.read_excel(fname, sheet_name = 0)

# %%
df1.head()
# Out:
#    Census Tract    DRAFT CES 4.0 Score  DRAFT CES 4.0 Percentile_results  \
# 0     6001407300             64.580115                         97.957125
# 1     6001408800             63.194836                         97.477932
# 2     6001409000             62.666135                         97.263556
# 3     6095250701             61.811844                         96.872636
# 4     6001409100             59.772651                         95.825977
#
#   DRAFT CES 4.0 \nPercentile Range    ZIP  2018 Total Population   Longitude  \
# 0         95-100% (highest scores)  94601                   2440 -122.210924
# 1         95-100% (highest scores)  94621                   7054 -122.196942
# 2         95-100% (highest scores)  94621                   3904 -122.221368
# 3         95-100% (highest scores)  94590                   3595 -122.244902
# 4         95-100% (highest scores)  94603                   2327 -122.183500
#
# ...

# %%
plt.figure(figsize=(16, 6))
sns.kdeplot(data=df1,x = 'Unemployment Pctl', hue= 'California County')
# Out:
# <AxesSubplot:xlabel='Unemployment Pctl', ylabel='Density'>

# %%
plt.figure(figsize=(16, 6))
sns.kdeplot(data=df1,x = 'Low Birth Weight Pctl', hue= 'California County')
# Out:
# <AxesSubplot:xlabel='Low Birth Weight Pctl', ylabel='Density'>

# %%
plt.figure(figsize=(16, 6))
sns.kdeplot(data=df1,x = 'Ozone Pctl', hue= 'California County')
# Out:
# <AxesSubplot:xlabel='Ozone Pctl', ylabel='Density'>

# %%
sns.jointplot(x = "Ozone Pctl", y='Low Birth Weight Pctl', hue= 'California County', data=df1, kind = 'kde')

# %%
plt.figure(figsize=(16, 6))
ax = sns.boxplot(x="California County", y="Ozone Pctl", data=df1)
